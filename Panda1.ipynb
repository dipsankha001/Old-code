# %%
import pandas as pd
import numpy as np
import xlrd
import xlsxwriter
from openpyxl.styles import Font
wb1=pd.ExcelFile(r'/Users/dip001/Documents/aa1.xlsx')
pd1=pd.read_excel(r'/Users/dip001/Documents/aa1.xlsx',sheet_name=None)

# %%
wb1.sheet_names
# Out:
# ['Exhibit 1', 'Sheet1', 'Sheet2']

# %%
list=pd1.columns.values

# %%
import xlsxwriter
workbook=xlsxwriter.Workbook('/Users/dip001/Documents/aa1.xlsx')

# %%
header_format = workbook.add_format({
    'bold': True,
    'text_wrap': True,
    'valign': 'top',
    'fg_color': '#D7E4BC',
    'border': 1})

# %%
writer = pd.ExcelWriter('/Users/dip001/Documents/aa1.xlsx',
                        engine='xlsxwriter')

# %%
pd1=pd.read_excel('/Users/dip001/Documents/aa1.xlsx',sheet_name=None)
pd1.to_excel(writer, sheet_name=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-223-4174f69ae6c6> in <module>
#       1 pd1=pd.read_excel('/Users/dip001/Documents/aa1.xlsx',sheet_name=None)
# ----> 2 pd1.to_excel(writer, sheet_name=None)
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'to_excel'

# %%
# Get the xlsxwriter objects from the dataframe writer object.
workbook  = writer.book
worksheet = writer.sheets['Exhibit 1']

# %%
pd1.head()
# Out:
#   ok issue 2010 2011 2012 2013 2014 [E]
# 0  c     c    c    c    c    c        c
# 1  c     c    c    c    c    c        c
# 2  c     c    c    c    c    c        c
# 3  c     c    c    c    c    c        c
# 4  c     c    c    c    c    c        c

# %%
pd1.to_excel(writer, sheet_name='Exhibit 1', startrow=1, header=False)
for col_num, value in enumerate(pd1.columns.values):
    worksheet.write(0, col_num , value, header_format)

# %%
writer.save()

# %%
pd1.head()
# Out:
#    level_0  index ok issue 2010 2011 2012 2013 2014 [E]
# 0        0      0  c     c    c    c    c    c        c
# 1        1      1  c     c    c    c    c    c        c
# 2        2      2  c     c    c    c    c    c        c
# 3        3      3  c     c    c    c    c    c        c
# 4        4      4  c     c    c    c    c    c        c

# %%
 pd1.drop(pd1.filter(regex="Unname"),axis=1, inplace=True)

# %%
pd1
# Out:
#   issue 2010 2011 2012 2013 2014 [E]
# 0     c    c    c    c    c        c
# 1     c    c    c    c    c        c
# 2     c    c    c    c    c        c
# 3     c    c    c    c    c        c
# 4     c    c    c    c    c        c
# 5     c    c    c    c    c        c
# 6     c    c    c    c    c        c
# 7     c    c    c    c    c        c
# 8     c    c    c    c    c        c
# 9     c    c    c    c    c        c

# %%
pd1.reset_index(drop=True)
# Out:
#   issue 2010 2011 2012 2013 2014 [E]
# 0     c    c    c    c    c        c
# 1     c    c    c    c    c        c
# 2     c    c    c    c    c        c
# 3     c    c    c    c    c        c
# 4     c    c    c    c    c        c
# 5     c    c    c    c    c        c
# 6     c    c    c    c    c        c
# 7     c    c    c    c    c        c
# 8     c    c    c    c    c        c
# 9     c    c    c    c    c        c

# %%
pd1
# Out:
#   issue 2010 2011 2012 2013 2014 [E]
# 0     c    c    c    c    c        c
# 1     c    c    c    c    c        c
# 2     c    c    c    c    c        c
# 3     c    c    c    c    c        c
# 4     c    c    c    c    c        c
# 5     c    c    c    c    c        c
# 6     c    c    c    c    c        c
# 7     c    c    c    c    c        c
# 8     c    c    c    c    c        c
# 9     c    c    c    c    c        c

# %%
pd1.to_excel(writer, sheet_name='Exhibit 1', index=False)

# %%
pd1
# Out:
#   issue 2010 2011 2012 2013 2014 [E]
# 0     c    c    c    c    c        c
# 1     c    c    c    c    c        c
# 2     c    c    c    c    c        c
# 3     c    c    c    c    c        c
# 4     c    c    c    c    c        c
# 5     c    c    c    c    c        c
# 6     c    c    c    c    c        c
# 7     c    c    c    c    c        c
# 8     c    c    c    c    c        c
# 9     c    c    c    c    c        c
